# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# ## Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'as', 'term', 'originated', 'of']

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
print('    batch:', [reverse_dictionary[bi] for bi in batch])
print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
#     batch: ['the', 'the', 'english', 'english', 'revolution', 'revolution', 'and', 'and']
#     labels: ['english', 'of', 'the', 'revolution', 'and', 'english', 'revolution', 'the']

# %% [markdown]
# # Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal(
            [vocabulary_size, embedding_size],
            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(valid_embeddings,
                           tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips,
                                                  skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.272574
# Nearest to more: mysteries, ifr, hyacinthus, literal, overkill, lived, behaviors, botanic,
# Nearest to there: cvn, damasus, overlapping, gillian, gradualism, lilongwe, eschatological, hubris,
# Nearest to or: maroon, hills, aeronautical, abelard, custody, bothwell, macphail, tequila,
# Nearest to other: delhi, philippines, unless, hardliners, schloss, magadha, alphege, desire,
# Nearest to the: storks, shrewsbury, anima, cetaceans, tallis, hunters, rtf, miniseries,
# Nearest to after: tallinn, roots, germanic, hopewell, cossack, overcast, resources, erasmus,
# Nearest to been: derives, failed, courland, dice, malignant, cave, directed, unclean,
# Nearest to many: londoners, ladakh, considerably, mpla, cerebrum, reassembled, bunker, probable,
# Nearest to history: tractatus, thumb, meshech, angeles, commentators, fellow, farmer, cy,
# Nearest to have: kimchi, allen, phobias, buddhas, stimulating, condenses, etymologies, communicator,
# Nearest to see: magie, viewers, taupin, teos, secrets, mifune, cacti, deakin,
# Nearest to and: vied, footprints, wield, deserving, tug, attracted, psychopathic, vocabularies,
# Nearest to in: resemblances, testing, flows, replete, cupola, imo, boomerangs, convents,
# Nearest to however: lucretius, potential, manuel, maquis, delaney, ay, reducing, trigger,
# Nearest to his: moroccan, ruhr, mcconnell, commonality, deathbed, glycolipids, swiss, subset,
# Nearest to seven: rearing, lows, vendetta, tarquinius, boxers, behavioral, livre, nkvd,
# Average loss at step 2000: 4.369026
# Average loss at step 4000: 3.870584
# Average loss at step 6000: 3.791304
# Average loss at step 8000: 3.691577
# Average loss at step 10000: 3.613798
# Nearest to more: botanic, mysteries, less, salaries, marsupials, mammalia, chic, devotee,
# Nearest to there: it, still, yassir, he, overtones, hideous, salle, coates,
# Nearest to or: and, aeronautical, temperature, jenny, hills, wild, custody, baumgarten,
# Nearest to other: untreated, these, philippines, ary, lovable, quaestor, penguin, lamm,
# Nearest to the: his, a, this, its, their, lament, an, laborers,
# Nearest to after: from, on, when, fraenkel, seeming, ratu, tallinn, longitudinal,
# Nearest to been: was, lived, by, directed, had, transcontinental, procol, be,
# Nearest to many: some, tunable, all, denial, dj, just, steppenwolf, dubs,
# Nearest to history: farmer, meshech, thumb, tractatus, fellow, waller, libraries, yoshi,
# Nearest to have: had, svg, has, be, are, allen, nih, never,
# Nearest to see: magie, taupin, har, teos, gaia, wild, maleficarum, references,
# Nearest to and: or, s, annibale, bede, hco, saved, heligoland, of,
# Nearest to in: of, on, from, at, with, during, borderline, virginals,
# Nearest to however: potential, unruly, ost, delaney, windowing, dusseldorf, crane, globes,
# Nearest to his: their, the, its, her, s, moroccan, paramount, this,
# Nearest to seven: six, eight, three, nine, four, five, zero, two,
# Average loss at step 12000: 3.605084
# Average loss at step 14000: 3.569926
# Average loss at step 16000: 3.412737
# Average loss at step 18000: 3.454053
# Average loss at step 20000: 3.540049
# Nearest to more: less, botanic, most, mysteries, chic, resistances, mammalia, fabled,
# Nearest to there: it, they, he, still, which, usually, tempted, who,
# Nearest to or: and, than, ramparts, though, illusion, registrations, unborn, therus,
# Nearest to other: many, these, some, ary, are, smokeless, several, such,
# Nearest to the: their, its, a, this, these, his, incorrectly, micronesia,
# Nearest to after: before, when, from, fraenkel, deo, tallinn, chrysostom, audio,
# Nearest to been: be, were, lived, by, had, decimals, directed, transcontinental,
# Nearest to many: some, all, several, other, these, most, tunable, denial,
# Nearest to history: thumb, tractatus, meshech, farmer, waller, conte, tony, obadiah,
# Nearest to have: had, has, be, were, svg, are, terence, never,
# Nearest to see: references, carbohydrate, har, parliamentarians, aforementioned, magie, can, jets,
# Nearest to and: or, but, metafont, in, heligoland, at, deontological, strewn,
# Nearest to in: at, on, with, among, from, and, between, by,
# Nearest to however: but, windowing, although, globes, yehoshua, dusseldorf, and, delaney,
# Nearest to his: their, her, its, the, several, moroccan, raucous, trouv,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Average loss at step 22000: 3.503174
# Average loss at step 24000: 3.489063
# Average loss at step 26000: 3.480238
# Average loss at step 28000: 3.478542
# Average loss at step 30000: 3.503920
# Nearest to more: less, very, most, rather, larger, chic, shakyamuni, marsupials,
# Nearest to there: they, it, he, still, we, usually, tempted, said,
# Nearest to or: and, than, hyacinthus, but, cher, faithless, der, who,
# Nearest to other: these, smokeless, various, quaestor, including, such, ary, some,
# Nearest to the: their, its, his, some, deification, a, tucum, automaton,
# Nearest to after: before, when, from, during, while, fraenkel, as, in,
# Nearest to been: become, be, were, was, already, lived, had, decimals,
# Nearest to many: some, several, these, all, various, both, most, dj,
# Nearest to history: thumb, waller, western, needless, source, translator, typhoon, doorman,
# Nearest to have: had, has, were, are, be, having, svg, never,
# Nearest to see: references, har, carbohydrate, nba, aforementioned, but, bangladeshis, yerushalmi,
# Nearest to and: or, but, in, who, however, koresh, kosi, of,
# Nearest to in: at, during, of, on, and, until, with, from,
# Nearest to however: but, although, and, windowing, dusseldorf, globes, yehoshua, though,
# Nearest to his: her, their, its, the, your, s, moroccan, this,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Average loss at step 32000: 3.498317
# Average loss at step 34000: 3.498518
# Average loss at step 36000: 3.451272
# Average loss at step 38000: 3.305046
# Average loss at step 40000: 3.430893
# Nearest to more: less, most, very, larger, resistances, rather, fabled, chic,
# Nearest to there: they, it, still, usually, he, which, tempted, also,
# Nearest to or: and, than, gry, parke, minions, a, mach, sociable,
# Nearest to other: different, various, amp, including, quaestor, topol, delhi, nagpur,
# Nearest to the: this, a, its, another, their, any, each, an,
# Nearest to after: before, when, during, from, while, cline, dissociated, deus,
# Nearest to been: be, become, was, were, already, lived, had, decimals,
# Nearest to many: some, several, these, various, both, those, all, most,
# Nearest to history: list, waller, doorman, politics, needless, stad, conte, northern,
# Nearest to have: had, has, were, be, are, feel, never, having,
# Nearest to see: references, list, but, aforementioned, har, carbohydrate, nba, favorable,
# Nearest to and: or, but, glycolysis, ed, omnipresent, in, checkpoint, remastered,
# Nearest to in: of, catalyse, isabel, from, with, tarleton, tributes, and,
# Nearest to however: but, although, that, though, globes, while, hestia, which,
# Nearest to his: her, their, its, your, s, moroccan, my, repeated,
# Nearest to seven: five, eight, nine, six, four, three, zero, two,
# Average loss at step 42000: 3.438295
# Average loss at step 44000: 3.456094
# Average loss at step 46000: 3.451164
# Average loss at step 48000: 3.352699
# Average loss at step 50000: 3.382495
# Nearest to more: less, most, very, larger, rather, resistances, highly, fabled,
# Nearest to there: they, it, he, she, said, still, tempted, who,
# Nearest to or: and, than, emphasising, hyacinthus, refering, measures, wakizashi, tar,
# Nearest to other: various, different, these, nagpur, topol, many, rebates, delhi,
# Nearest to the: their, his, its, a, this, any, transclusion, some,
# Nearest to after: before, when, during, while, from, cline, through, since,
# Nearest to been: become, be, already, was, were, lived, decimals, had,
# Nearest to many: some, several, these, both, various, those, such, numerous,
# Nearest to history: doorman, list, waller, thumb, kiev, quotients, politics, turf,
# Nearest to have: had, has, were, be, are, feel, having, never,
# Nearest to see: references, wma, list, umbra, maleficarum, carbohydrate, aforementioned, colored,
# Nearest to and: or, but, hairpin, of, painfully, tetrahedral, antoine, however,
# Nearest to in: during, of, on, from, within, since, at, until,
# Nearest to however: but, although, that, while, though, when, since, hestia,
# Nearest to his: their, her, its, your, my, the, gaba, s,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Average loss at step 52000: 3.435954
# Average loss at step 54000: 3.425439
# Average loss at step 56000: 3.435569
# Average loss at step 58000: 3.397167
# Average loss at step 60000: 3.393209
# Nearest to more: less, rather, larger, most, very, fabled, highly, better,
# Nearest to there: they, it, now, still, she, usually, he, this,
# Nearest to or: and, than, prog, measures, coalesced, mya, interdependent, biographical,
# Nearest to other: various, different, including, nagpur, many, tunneling, older, mathfrak,
# Nearest to the: their, its, a, this, aetius, some, any, dwarfed,
# Nearest to after: before, during, when, while, from, until, although, dissociated,
# Nearest to been: be, become, were, already, was, decimals, lived, ammanati,
# Nearest to many: some, several, these, various, both, most, numerous, those,
# Nearest to history: politics, list, kiev, geography, demographics, auditorium, needless, writings,
# Nearest to have: has, had, are, include, having, were, be, feel,
# Nearest to see: references, but, wma, list, ch, mcgregor, colored, umbra,
# Nearest to and: or, but, asch, for, although, however, including, carnap,
# Nearest to in: within, during, of, since, at, among, between, until,
# Nearest to however: but, although, that, since, which, though, while, and,
# Nearest to his: her, their, its, my, your, nominees, the, baronet,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Average loss at step 62000: 3.240387
# Average loss at step 64000: 3.255132
# Average loss at step 66000: 3.406859
# Average loss at step 68000: 3.398576
# Average loss at step 70000: 3.356445
# Nearest to more: less, most, larger, very, rather, highly, fabled, shakyamuni,
# Nearest to there: they, it, he, still, we, she, usually, now,
# Nearest to or: and, than, any, the, for, without, enforceable, of,
# Nearest to other: different, various, tunneling, many, delhi, topol, others, nagpur,
# Nearest to the: its, their, any, this, a, another, some, aetius,
# Nearest to after: before, during, when, while, rochelle, dissociated, until, from,
# Nearest to been: be, become, was, already, were, largely, had, decimals,
# Nearest to many: some, several, these, various, both, most, numerous, those,
# Nearest to history: list, politics, auditorium, thermochemistry, prinz, macromolecules, demographics, laborers,
# Nearest to have: had, has, are, were, having, include, feel, be,
# Nearest to see: references, include, list, wma, but, refer, maleficarum, bloodiest,
# Nearest to and: or, but, upgrades, while, however, pca, olive, to,
# Nearest to in: on, within, during, throughout, for, among, since, conveys,
# Nearest to however: but, although, since, though, while, that, where, which,
# Nearest to his: her, their, its, your, my, the, impressively, nominees,
# Nearest to seven: four, six, eight, nine, five, three, two, zero,
# Average loss at step 72000: 3.370324
# Average loss at step 74000: 3.349609
# Average loss at step 76000: 3.317635
# Average loss at step 78000: 3.347129
# Average loss at step 80000: 3.379491
# Nearest to more: less, very, most, larger, rather, highly, shakyamuni, quite,
# Nearest to there: it, they, he, still, she, we, usually, often,
# Nearest to or: and, than, while, lim, anthems, diagnostics, illegally, but,
# Nearest to other: various, different, older, handlebars, others, jenny, many, including,
# Nearest to the: each, this, its, their, a, his, another, every,
# Nearest to after: before, during, when, while, until, from, rochelle, despite,
# Nearest to been: become, be, already, was, were, largely, decimals, bfi,
# Nearest to many: some, several, various, both, these, most, numerous, those,
# Nearest to history: list, lip, politics, rejection, auditorium, needless, writings, version,
# Nearest to have: had, has, having, be, are, were, include, feel,
# Nearest to see: references, include, but, according, maleficarum, mcgregor, refer, called,
# Nearest to and: or, but, pstn, including, olive, hams, bewildering, while,
# Nearest to in: during, within, at, on, throughout, gokturks, among, until,
# Nearest to however: although, but, that, while, though, since, where, avian,
# Nearest to his: her, their, my, its, your, the, baronet, drops,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Average loss at step 82000: 3.409453
# Average loss at step 84000: 3.410667
# Average loss at step 86000: 3.387335
# Average loss at step 88000: 3.352674
# Average loss at step 90000: 3.361915
# Nearest to more: less, very, most, rather, larger, highly, merry, shakyamuni,
# Nearest to there: they, it, he, she, still, we, now, generally,
# Nearest to or: and, swiftly, while, than, supplemental, contradicting, gleaming, polymerase,
# Nearest to other: various, different, including, individual, heritable, older, delhi, attractive,
# Nearest to the: its, a, this, his, each, micronesia, their, any,
# Nearest to after: before, during, when, while, until, despite, without, if,
# Nearest to been: become, be, already, was, decimals, largely, bfi, ammanati,
# Nearest to many: some, several, these, various, both, numerous, all, most,
# Nearest to history: list, politics, lip, thermochemistry, needless, auditorium, macromolecules, doorman,
# Nearest to have: had, has, were, having, are, be, include, feel,
# Nearest to see: references, include, external, list, includes, maleficarum, wma, ahijah,
# Nearest to and: or, but, civilis, while, australes, kosi, hairpin, nobody,
# Nearest to in: during, within, at, under, on, mana, between, with,
# Nearest to however: but, although, that, though, since, while, where, erythromycin,
# Nearest to his: her, their, its, my, your, s, the, nominees,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Average loss at step 92000: 3.397157
# Average loss at step 94000: 3.251178
# Average loss at step 96000: 3.356215
# Average loss at step 98000: 3.240619
# Average loss at step 100000: 3.359650
# Nearest to more: less, very, most, larger, quite, highly, rather, shakyamuni,
# Nearest to there: they, he, it, we, still, now, generally, she,
# Nearest to or: and, than, lim, while, excepted, eclac, obelix, aggressively,
# Nearest to other: various, others, individual, different, older, including, commercial, mathfrak,
# Nearest to the: their, its, his, a, your, this, whose, aetius,
# Nearest to after: before, during, when, while, without, until, despite, although,
# Nearest to been: become, be, already, was, ammanati, were, decimals, largely,
# Nearest to many: several, some, various, these, numerous, those, few, both,
# Nearest to history: list, politics, lip, thermochemistry, needless, widths, novarum, science,
# Nearest to have: had, has, were, include, are, be, having, feel,
# Nearest to see: references, includes, external, include, list, ahijah, refer, according,
# Nearest to and: or, but, while, when, of, wherever, however, like,
# Nearest to in: during, within, on, throughout, from, until, of, at,
# Nearest to however: but, although, though, that, where, while, especially, since,
# Nearest to his: her, their, my, its, your, the, our, s,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# # Problem
# -------
#
# * An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
from itertools import compress
data_index = 0
def generate_batch_cbow(batch_size, num_skips, skip_window):
    '''
    Batch generator for CBOW (Continuous Bag of Words).
    batch should be a shape of (batch_size, num_skips)
    Parameters
    ----------
    data: list of index of words
    batch_size: number of words in each mini-batch
    num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
    skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
    '''
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span) # used for collecting data[data_index] in the sliding window
    # collect the first window of words
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # move the sliding window  
    for i in range(batch_size):
        mask = [1] * span
        mask[skip_window] = 0 
        batch[i, :] = list(compress(buffer, mask)) # all surrounding words
        labels[i, 0] = buffer[skip_window] # the word at the center 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
#     print(batch)
    print('    batch:', [[reverse_dictionary[bi[n]] for n in range(num_skips)] for bi in batch])
    print('\n    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
#     train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal(
            [vocabulary_size, embedding_size],
            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
#     embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    embed = tf.zeros([batch_size, embedding_size])
    for j in range(num_skips):
        embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
    
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(valid_embeddings,
                           tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_cbow(batch_size, num_skips,
                                                  skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.366107
# Nearest to to: utterances, promulgation, sudetenland, modulated, retold, view, landslides, cabinda,
# Nearest to it: resembling, gogo, fishing, yerba, congregationalist, cryptology, ige, longitude,
# Nearest to his: routinely, homogeneous, maggiore, nathan, fairbanks, dachshunds, minimising, siam,
# Nearest to at: freeport, evacuate, harvesting, caravans, conspired, parsing, questionnaire, grassroots,
# Nearest to for: fetched, imr, centurion, mechanic, laughter, karma, persson, thrilling,
# Nearest to are: satire, christof, outgrowth, jacobite, isolationist, seuss, reconciliation, weil,
# Nearest to five: euros, muddy, incendiary, airstream, boundless, coprophagia, precise, guidebook,
# Nearest to other: everybody, cms, pompeius, gz, melody, supplanted, javascript, aldrich,
# Nearest to war: wcw, brooker, rapid, lovecraftian, guayaquil, theological, downturn, mandeville,
# Nearest to will: interwoven, separately, intensely, averroes, crossbows, nationhood, forestall, homonyms,
# Nearest to united: unimportant, superior, itt, slogan, nonviolent, parchment, ceremony, retelling,
# Nearest to a: procopius, prompt, nest, boycott, britannica, hiragana, festivities, cristae,
# Nearest to up: surnames, forensics, cunha, brothers, transpose, inputs, hurling, undulating,
# Nearest to he: maghrib, stubby, anglia, repairs, restorer, preis, childress, ioan,
# Nearest to while: maronites, fudge, arising, lobbies, anesthetic, kathryn, uncertainty, nobel,
# Nearest to of: supersede, discus, handhelds, kinnear, localised, ingalls, commodores, agrarian,
# Average loss at step 2000: 4.090911
# Average loss at step 4000: 3.555191
# Average loss at step 6000: 3.385615
# Average loss at step 8000: 3.234539
# Average loss at step 10000: 3.168572
# Nearest to to: could, would, should, weathering, will, saccharomyces, can, falsify,
# Nearest to it: he, this, there, they, she, which, barometer, imf,
# Nearest to his: their, her, the, its, conflicts, baths, extremophiles, lees,
# Nearest to at: in, courageous, tampering, cannibals, conspired, aquaculture, on, graduating,
# Nearest to for: with, thrilling, ringworld, wattle, in, gateway, as, uruguayan,
# Nearest to are: were, is, remix, heal, have, kimberley, neuropathy, nils,
# Nearest to five: six, eight, seven, three, four, nine, zero, two,
# Nearest to other: many, some, several, submissions, saudi, gymnosperms, nina, zangger,
# Nearest to war: hegel, opportunistic, sonic, bata, rapid, libi, belief, benhavn,
# Nearest to will: can, could, would, may, must, should, to, rearranging,
# Nearest to united: alabama, retelling, jeff, slogan, fringed, unimportant, prefixes, bing,
# Nearest to a: expos, no, the, cobain, eulogy, fenced, shortcut, draught,
# Nearest to up: ecowas, oswald, faraway, taif, forensics, kbit, turkeys, nasa,
# Nearest to he: it, she, they, who, there, steve, khazars, mifune,
# Nearest to while: bunch, arising, with, maronites, imr, decorative, kronecker, superpowers,
# Nearest to of: minicomputers, caston, in, commodores, inflating, same, liquors, reconciling,
# Average loss at step 12000: 3.202465
# Average loss at step 14000: 3.153302
# Average loss at step 16000: 3.172360
# Average loss at step 18000: 3.124170
# Average loss at step 20000: 2.987850
# Nearest to to: utterances, will, saccharomyces, ortho, would, pantheistic, must, should,
# Nearest to it: he, she, there, this, but, they, which, convenient,
# Nearest to his: their, her, its, the, s, squalor, whose, my,
# Nearest to at: during, in, on, falcons, overwrite, within, mud, intimidated,
# Nearest to for: thrilling, vostok, highest, forged, in, of, misogyny, miniscule,
# Nearest to are: were, have, is, heal, include, remix, lodovico, be,
# Nearest to five: six, seven, eight, three, four, zero, nine, two,
# Nearest to other: different, others, various, several, olfactory, minivans, repressive, comprising,
# Nearest to war: bata, sonic, duron, libi, questioner, opportunistic, stripper, deduces,
# Nearest to will: can, would, may, could, must, should, might, cannot,
# Nearest to united: alabama, retelling, apl, jeff, bing, slogan, anatolian, parodies,
# Nearest to a: the, any, no, another, promoters, bamako, pedestrians, limerick,
# Nearest to up: him, them, over, oswald, faraway, blur, ecowas, out,
# Nearest to he: it, she, they, who, there, i, we, monophosphate,
# Nearest to while: when, but, arising, and, bunch, although, harcourt, crops,
# Nearest to of: in, empirical, biz, errand, touchstone, minicomputers, shilton, jurisdictional,
# Average loss at step 22000: 3.073870
# Average loss at step 24000: 3.038606
# Average loss at step 26000: 3.007390
# Average loss at step 28000: 3.030152
# Average loss at step 30000: 3.005826
# Nearest to to: saccharomyces, can, sudetenland, would, could, forged, will, pantheistic,
# Nearest to it: he, she, there, this, they, pros, what, imf,
# Nearest to his: her, their, its, my, whose, hurdler, the, worries,
# Nearest to at: in, within, caravans, during, germinal, fijians, ithilien, rudolf,
# Nearest to for: vostok, thrilling, vanquish, including, uruguayan, afghan, fireman, against,
# Nearest to are: were, have, is, include, do, including, heal, lodovico,
# Nearest to five: four, six, seven, eight, nine, three, zero, two,
# Nearest to other: different, many, various, others, these, several, historical, fades,
# Nearest to war: sonic, neoconservative, opportunistic, duron, bata, mercenaries, teachers, bridgeport,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to united: alabama, anatolian, unoccupied, apl, city, retelling, kowalski, archimandrite,
# Nearest to a: the, another, sparsely, any, prickly, isomorphic, pedestrians, little,
# Nearest to up: out, off, him, them, down, over, faraway, forensics,
# Nearest to he: she, it, they, who, there, we, eventually, then,
# Nearest to while: when, although, however, profoundly, but, antlia, harcourt, after,
# Nearest to of: in, empirical, contaminants, kinnear, praeger, like, qassam, from,
# Average loss at step 32000: 2.822312
# Average loss at step 34000: 2.952320
# Average loss at step 36000: 2.950074
# Average loss at step 38000: 2.938740
# Average loss at step 40000: 2.927110
# Nearest to to: utterances, will, saccharomyces, must, modulated, vella, apotheosis, would,
# Nearest to it: he, she, there, this, they, never, which, imf,
# Nearest to his: her, their, my, its, our, your, the, whose,
# Nearest to at: bertolt, overwrite, invisible, during, near, in, under, nowell,
# Nearest to for: after, when, pf, thrilling, galina, vostok, including, wattle,
# Nearest to are: were, have, beginners, although, is, include, including, atolls,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to other: various, others, kazakhstani, different, western, many, distinct, some,
# Nearest to war: teachers, sacramento, duron, bridgeport, happiness, adrift, bata, neoconservative,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to united: alabama, unoccupied, retelling, washington, apl, qing, psyche, nation,
# Nearest to a: another, polski, the, kuru, prickly, apprenticed, siculus, sparsely,
# Nearest to up: out, off, down, them, him, back, over, faraway,
# Nearest to he: she, it, they, there, who, we, eventually, furthered,
# Nearest to while: although, when, but, and, however, though, like, after,
# Nearest to of: touchstone, errand, cannibalistic, levant, beverly, including, townsfolk, crochet,
# Average loss at step 42000: 2.946438
# Average loss at step 44000: 2.957797
# Average loss at step 46000: 2.908210
# Average loss at step 48000: 2.869426
# Average loss at step 50000: 2.851554
# Nearest to to: should, will, rhapsody, saccharomyces, towards, jolson, ortho, sudetenland,
# Nearest to it: he, she, there, this, they, what, which, terrific,
# Nearest to his: her, their, my, its, our, your, whose, twickenham,
# Nearest to at: during, in, near, under, on, tampering, overwrite, hijackers,
# Nearest to for: thrilling, after, if, when, uruguayan, ringworld, including, seele,
# Nearest to are: were, is, have, include, be, including, although, atolls,
# Nearest to five: four, seven, eight, three, six, nine, zero, two,
# Nearest to other: others, various, different, grateful, gianfranco, western, woolfson, distinct,
# Nearest to war: duron, ragtime, neoconservative, mercenaries, champion, feminine, beale, sacramento,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to united: nation, retelling, alabama, qing, same, unoccupied, apl, washington,
# Nearest to a: any, the, another, bolo, alga, kuru, every, surfers,
# Nearest to up: out, off, them, down, him, back, over, together,
# Nearest to he: she, it, they, there, who, later, we, eventually,
# Nearest to while: although, when, after, before, but, though, were, during,
# Nearest to of: contaminants, in, during, hazlitt, caso, including, regarding, shahanshah,
# Average loss at step 52000: 2.895274
# Average loss at step 54000: 2.865433
# Average loss at step 56000: 2.854866
# Average loss at step 58000: 2.748571
# Average loss at step 60000: 2.829830
# Nearest to to: should, will, saccharomyces, must, could, would, damme, towards,
# Nearest to it: he, she, there, this, what, they, nupedia, itself,
# Nearest to his: her, their, its, my, our, your, whose, the,
# Nearest to at: during, in, near, under, on, germinal, within, overwrite,
# Nearest to for: without, thrilling, scottie, against, feign, ursinus, pf, steamships,
# Nearest to are: were, is, include, have, remain, neuropathy, atolls, although,
# Nearest to five: seven, six, four, eight, nine, three, zero, two,
# Nearest to other: various, others, gianfranco, different, erupted, interrogative, rodrigues, uematsu,
# Nearest to war: feminine, teachers, ragtime, eagle, libi, password, antiquaries, instill,
# Nearest to will: would, could, can, must, should, might, may, cannot,
# Nearest to united: nation, pars, retelling, qing, apl, tractates, huntingdon, spanish,
# Nearest to a: another, apprenticed, the, gabbro, nonaggression, bolo, kuru, isomorphic,
# Nearest to up: off, out, him, them, down, back, together, away,
# Nearest to he: she, it, they, there, who, farad, we, eventually,
# Nearest to while: although, when, though, however, before, after, during, but,
# Nearest to of: although, touchstone, commodores, including, cheerleader, from, firestone, in,
# Average loss at step 62000: 2.835379
# Average loss at step 64000: 2.773914
# Average loss at step 66000: 2.765206
# Average loss at step 68000: 2.713318
# Average loss at step 70000: 2.788296
# Nearest to to: saccharomyces, would, will, towards, should, utterances, could, pantheistic,
# Nearest to it: she, he, there, this, they, expansionist, nupedia, not,
# Nearest to his: her, their, its, my, our, whose, your, the,
# Nearest to at: near, during, in, on, under, around, within, behind,
# Nearest to for: thrilling, including, miniscule, in, afghan, eleventh, scottie, feign,
# Nearest to are: were, include, have, is, contain, civilize, those, remain,
# Nearest to five: seven, six, eight, three, nine, four, zero, two,
# Nearest to other: various, individual, ranging, different, comprising, gianfranco, megafauna, others,
# Nearest to war: feminine, teachers, eagle, wars, ragtime, duron, champion, beale,
# Nearest to will: would, could, can, must, should, might, may, cannot,
# Nearest to united: nation, retelling, colorado, confederate, tractates, pars, qing, federated,
# Nearest to a: the, any, grumman, another, gabbro, expos, sparsely, too,
# Nearest to up: off, out, back, him, down, together, them, mate,
# Nearest to he: she, it, they, there, who, we, farad, never,
# Nearest to while: although, when, after, before, though, however, but, unspoiled,
# Nearest to of: touchstone, contaminants, including, in, caso, cheerleader, although, firestone,
# Average loss at step 72000: 2.799328
# Average loss at step 74000: 2.641110
# Average loss at step 76000: 2.804344
# Average loss at step 78000: 2.828100
# Average loss at step 80000: 2.783238
# Nearest to to: saccharomyces, should, towards, burgnich, ortho, rolle, will, vella,
# Nearest to it: he, she, there, this, today, they, we, nupedia,
# Nearest to his: her, their, my, its, your, our, whose, choruses,
# Nearest to at: near, during, in, under, throughout, germinal, socratic, strasberg,
# Nearest to for: when, after, thrilling, without, while, against, uruguayan, although,
# Nearest to are: were, have, include, is, remain, exist, contain, although,
# Nearest to five: six, seven, eight, four, three, nine, two, zero,
# Nearest to other: various, numerous, individual, equilibria, others, georgian, fades, squares,
# Nearest to war: feminine, wars, teachers, cup, enosis, incompetent, champion, ragtime,
# Nearest to will: would, could, can, should, must, might, may, cannot,
# Nearest to united: nation, confederate, german, u, retelling, federated, tractates, evaluates,
# Nearest to a: another, the, gabbro, grumman, yao, expos, prickly, gaunt,
# Nearest to up: off, down, out, back, him, together, them, away,
# Nearest to he: she, it, they, there, we, who, i, farad,
# Nearest to while: although, when, after, though, before, hissarlik, but, for,
# Nearest to of: commodores, touchstone, and, in, cheerleader, during, including, lettre,
# Average loss at step 82000: 2.664966
# Average loss at step 84000: 2.771278
# Average loss at step 86000: 2.737461
# Average loss at step 88000: 2.758404
# Average loss at step 90000: 2.738207
# Nearest to to: saccharomyces, would, should, might, towards, could, modulated, vella,
# Nearest to it: he, she, there, this, they, nothing, minnesotans, terrific,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to at: near, in, during, on, under, germinal, around, invisible,
# Nearest to for: after, when, thrilling, although, genocidal, felsic, differentiable, hsbc,
# Nearest to are: were, is, have, include, remain, including, civilize, contain,
# Nearest to five: six, four, seven, three, eight, zero, nine, two,
# Nearest to other: various, others, individual, squares, sacraments, grammatical, numerous, villages,
# Nearest to war: wars, teachers, feminine, enosis, cup, champion, incompetent, bankruptcy,
# Nearest to will: would, could, must, can, should, might, may, cannot,
# Nearest to united: nation, confederate, kowalski, federated, retelling, panhandle, pars, apl,
# Nearest to a: another, the, expos, kuru, grumman, enough, nonaggression, brouwer,
# Nearest to up: off, out, down, back, together, him, them, away,
# Nearest to he: she, it, they, there, who, quickly, we, originally,
# Nearest to while: although, though, when, before, began, after, but, fasts,
# Nearest to of: commodores, journ, through, concerning, solitary, errand, lettre, hemispheres,
# Average loss at step 92000: 2.676830
# Average loss at step 94000: 2.721409
# Average loss at step 96000: 2.704185
# Average loss at step 98000: 2.369049
# Average loss at step 100000: 2.399079
# Nearest to to: must, should, will, saccharomyces, might, towards, shall, could,
# Nearest to it: he, she, there, this, itself, nothing, never, today,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to at: near, during, in, on, after, palatinate, under, taxpayers,
# Nearest to for: after, when, without, against, thrilling, miniscule, during, deregulation,
# Nearest to are: were, have, include, remain, is, contain, exist, atolls,
# Nearest to five: seven, six, eight, four, nine, three, zero, two,
# Nearest to other: others, western, various, kazakhstani, ritually, squares, villages, grammatical,
# Nearest to war: wars, incompetent, enosis, beale, anarchy, champion, teachers, feminine,
# Nearest to will: would, could, must, can, might, should, cannot, may,
# Nearest to united: confederate, nation, panhandle, colorado, independent, caribbean, retelling, kowalski,
# Nearest to a: grumman, another, expos, rogues, argento, klement, annoyed, oneself,
# Nearest to up: off, out, together, down, back, him, them, away,
# Nearest to he: she, they, it, there, who, we, even, finally,
# Nearest to while: although, though, before, but, when, began, after, however,
# Nearest to of: qassam, touchstone, in, cheerleader, commodores, firestone, hemorrhagic, rhondda,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
